# %%
import numpy as np

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-1,1,0.001)
yt=3*x+2+(np.random.randn(len(x)))
y=3*x+2
plt.plot(x,yt,'o')
plt.plot(x,y,'r')

# %% [markdown]
# $
# L=\frac{1}{2n}\sum_i^n(y_p^i-y_t^i)^2
# $
#
#
# $
# \theta_1 = \theta_1 - \alpha \frac{\partial L}{\partial\theta}$

# %%
theta1 = 0.0
theta2 = 0.0
alpha = 0.1

def yp(x):
    global theta1,theta2
    return theta1*x+theta2
plt.plot(x,yt,'o')
for i in range(100):
    theta1 = theta1 - alpha*np.average((yp(x) - yt)*x)
    theta2 = theta2 - alpha*np.average((yp(x) - yt))
    if i%10==0 :
        print(theta1,theta2)
        plt.plot(x,theta1*x+theta2,'r')
# Out:
# 0.10027404474260947 0.19821579912981477
# 0.9367601831126322 1.3603159085447392
# 1.5330496561044202 1.7657358629783664
# 1.957999432810415 1.90725435873649
# 2.2608025823448807 1.9567108970232916
# 2.476554642089987 1.974035193255265
# 2.630276528107764 1.9801327075818451
# 2.7398006299440953 1.9822993239028788
# 2.8178340047224526 1.983083663415482
# 2.8734307618404404 1.9833777270387085

# %% [markdown]
# # Activity 3

# %%
n=200
def normal(n):
    return np.random.randn(n)
x1=np.concatenate((normal(n)-2,normal(n)+2),axis=None)
x2=np.concatenate((normal(n)-2,normal(n)+2),axis=None)
yt=np.ones(2*n)
yt[:n]=-1
plt.plot(x1[yt==-1],x2[yt==-1],'or')
plt.plot(x1[yt==1],x2[yt==1],'ob')

# %%
theta1 = 0.0
theta2 = 0.0
theta3 = 0.0
alpha = 0.1
step = 0.1
mx2,mx1 = np.mgrid[slice(-5,5+step,step),
                    slice(-5,5+step,step)]
def func_yp(x1,x2):
    global theta1,theta2,theta3
    z=theta1*x1 + theta2*x2 + theta3
    return np.tanh(z)
plt.plot(x1[yt==-1],x2[yt==-1],'or')
plt.plot(x1[yt==1],x2[yt==1],'ob')
for i in range(100):
    yp = func_yp(x1,x2)
    theta1 = theta1 - alpha*np.average((yp - yt)*(1-pow(yp,2))*x1)
    theta2 = theta2 - alpha*np.average((yp - yt)*(1-pow(yp,2))*x2)
    theta3 = theta3 - alpha*np.average((yp - yt)*(1-pow(yp,2)))
    if i%10==0 :
        print(theta1,theta2,theta3)
        #plt.plot(x,theta1*x1+theta2*x2+theta3,'r')
cmap = plt.get_cmap('RdYlBu')
plt.pcolormesh(mx1,mx2,func_yp(mx1,mx2),cmap=cmap,vmin=-2,vmax=1.5)
# Out:
# 0.19703858799005536 0.19942310636041982 0.0
# 0.35496789643907556 0.3619215660474185 0.0022024131250784926
# 0.4115321197543909 0.4243334959790537 0.003354553072580465
# 0.44792037790657385 0.46632188107097855 0.00395755995323543
# 0.47502580588148025 0.49865392167250905 0.004196517151783262
# 0.49672762181378527 0.5252269006339121 0.004170208052015983
# 0.5148763364881638 0.5479305078443097 0.003940015822153037
# 0.5305049654921746 0.5678359826837401 0.0035475592708581367
# 0.5442509665864927 0.5856138827161814 0.0030227351985167438
# 0.5565362399927459 0.6017139235264453 0.00238792993395312
