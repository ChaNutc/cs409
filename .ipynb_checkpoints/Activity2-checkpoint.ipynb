# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-1,1,0.001)
yt=3*x+2+(np.random.randn(len(x)))
y=3*x+2
plt.plot(x,yt,'o')
plt.plot(x,y,'r')

# %% [markdown]
# $
# L=\frac{1}{2n}\sum_i^n(y_p^i-y_t^i)^2
# $
#
#
# $
# \theta_1 = \theta_1 - \alpha \frac{\partial L}{\partial\theta}$

# %%
theta1 = 0.0
theta2 = 0.0
alpha = 0.1

def yp(x):
    global theta1,theta2
    return theta1*x+theta2
plt.plot(x,yt,'o')
for i in range(100):
    theta1 = theta1 - alpha*np.average((yp(x) - yt)*x)
    theta2 = theta2 - alpha*np.average((yp(x) - yt))
    if i%10==0 :
        print(theta1,theta2)
        plt.plot(x,theta1*x+theta2,'r')
# Out:
# 0.09908870625579358 0.20145063474069694
# 0.9256971103546584 1.3825108806169928
# 1.5149541539441267 1.7945392218763005
# 1.934895329311752 1.9383600652851476
# 2.23413062212109 1.9886180616957831
# 2.4473409048769117 2.006220868128158
# 2.599251923626468 2.0124148225822793
# 2.707485860746313 2.014614587886998
# 2.784600039184456 2.0154101454569626
# 2.839541898314735 2.015707878137763
